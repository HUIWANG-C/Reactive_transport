# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

from readfile import *

case="/mnt/disk2/OPTOD_040725/n13/1_Surface_decay_2d/Particle1e5/Pe1e2/n13_Da_1e0/output"
path=detect_file_path(case, 'absorption')
print(path)
# Out:
# Using file: /mnt/disk2/OPTOD_040725/n13/1_Surface_decay_2d/Particle1e5/Pe1e2/n13_Da_1e0/output/Data_absorption_time_M_advection_diffusion_surface_decay_2d_C_n13_Da_1e0_OF_flow_b_T_Pe_1e2_R_Da_1e0_S_1e-1_1e-3_1e5_I_fluxweighted_O_moments_breakthrough_mass_1e-3_RUN_0.dat
# /mnt/disk2/OPTOD_040725/n13/1_Surface_decay_2d/Particle1e5/Pe1e2/n13_Da_1e0/output/Data_absorption_time_M_advection_diffusion_surface_decay_2d_C_n13_Da_1e0_OF_flow_b_T_Pe_1e2_R_Da_1e0_S_1e-1_1e-3_1e5_I_fluxweighted_O_moments_breakthrough_mass_1e-3_RUN_0.dat

# %%
bt=breakthrough_time(case)
# Out:
# Using file: /mnt/disk2/OPTOD_040725/n13/1_Surface_decay_2d/Particle1e5/Pe1e2/n13_Da_1e0/output/Data_absorption_time_M_advection_diffusion_surface_decay_2d_C_n13_Da_1e0_OF_flow_b_T_Pe_1e2_R_Da_1e0_S_1e-1_1e-3_1e5_I_fluxweighted_O_moments_breakthrough_mass_1e-3_RUN_0.dat
# Breakthrough time: t= 4583.13772

# %%
pathmass=detect_file_path(case, 'Data_mass_M')
time_full, mass_full, time_BT, mass_BT=read_Mass_file(pathmass,bt)
# Out:
# Using file: /mnt/disk2/OPTOD_040725/n13/1_Surface_decay_2d/Particle1e5/Pe1e2/n13_Da_1e0/output/Data_mass_M_advection_diffusion_surface_decay_2d_C_n13_Da_1e0_OF_flow_b_T_Pe_1e2_R_Da_1e0_S_1e-1_1e-3_1e5_I_fluxweighted_O_moments_breakthrough_mass_1e-3_RUN_0.dat

# %%
plt.plot(time_full,mass_full)
plt.plot(time_BT,mass_BT)

# %%
print(time_full)
# Out:
# [ 7357.11928 15669.9336   8457.41443 ...  7361.12188  8266.81359
#  10473.7259 ]
